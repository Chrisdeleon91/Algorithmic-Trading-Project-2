# %%
# Save the DataFrame to a CSV file
# df.to_csv('your_file_name.csv', index=False)

# %%
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
import time
import backtrader as bt
import pandas as pd
import yfinance as yf

# Initialize Alpaca API
api = tradeapi.REST('PKD8BNDR0EC8XAJCLZDY', 'gAgLE5vv1g90cncwc0SQO4K13TeeFwI2gr7caf7p', base_url='https://paper-api.alpaca.markets')  # Use the paper trading API for testing

# Define your prediction data or replace this with loading your actual prediction data
# Example: Replace this with predictions_df = load_your_predictions_data()

predictions_df = pd.read_csv('Resources\ETH_AUG_predictions.csv')

# Define a Backtrader strategy
class MyStrategy(bt.Strategy):
    def __init__(self):
        pass

    def next(self):
        # Get the current date and time
        current_datetime = self.datetime.datetime()
        current_hour = current_datetime.strftime('%H:%M:%S')

        # Slice the predictions based on the current date and hour
        signal = predictions_df["Predicted"].loc[f'{current_datetime} {current_hour}']

        # Get account information to check available quantity of BTCUSD
        position_info = api.get_position('ETHUSD')
        btcusd_qty_available = float(position_info.qty)

        # Execute trades based on your signals
        if signal == 1 and btcusd_qty_available > 0:
            # Place a market order to buy
            self.buy(data=self.datas[0], size=1)
        elif signal == -1 and btcusd_qty_available > 0:
            # Place a market order to sell
            self.sell(data=self.datas[0], size=1)

# Define the Backtrader data feed
class AlpacaData(bt.feeds.GenericCSVData):
    params = (
        ('datetime', 0),
        ('open', 1),
        ('high', 2),
        ('low', 3),
        ('close', 4),
        ('volume', 5),
        ('openinterest', -1),
    )

# Create a Backtrader Cerebro engine
cerebro = bt.Cerebro()

# Add the Alpaca data feed
#data = AlpacaData(dataname='path_to_your_price_data.csv', timeframe=bt.TimeFrame.Days)
#data = bt.feeds.YahooFinanceCSVData(dataname='Resources/ETH-USD.csv')
data = yf.download('ETH-USD')
cerebro.adddata(data)

# Add the strategy
cerebro.addstrategy(MyStrategy)

# Run the backtest
cerebro.run()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25092\1986258909.py in ?()
#      56 # Add the Alpaca data feed
#      57 #data = AlpacaData(dataname='path_to_your_price_data.csv', timeframe=bt.TimeFrame.Days)
#      58 #data = bt.feeds.YahooFinanceCSVData(dataname='Resources/ETH-USD.csv')
#      59 data = yf.download('ETH-USD')
# ---> 60 cerebro.adddata(data)
#      61
#      62 # Add the strategy
#      63 cerebro.addstrategy(MyStrategy)
#
# c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\cerebro.py in ?(self, data, name)
#     759         if name is not None:
#     760             data._name = name
#     761
#     762         data._id = next(self._dataid)
# --> 763         data.setenvironment(self)
#     764
#     765         self.datas.append(data)
#     766         self.datasbyname[data._name] = data
#
# c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'setenvironment'

# %%
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
import time
import backtrader as bt
import pandas as pd
import yfinance as yf

# Initialize Alpaca API
api = tradeapi.REST('PKD8BNDR0EC8XAJCLZDY', 'gAgLE5vv1g90cncwc0SQO4K13TeeFwI2gr7caf7p', base_url='https://paper-api.alpaca.markets')  # Use the paper trading API for testing

# Define your prediction data or replace this with loading your actual prediction data
predictions_df = pd.read_csv('ETH_AUG_predictions.csv', index_col="date", parse_dates=True, infer_datetime_format=True)

# Define a Backtrader strategy
class MyStrategy(bt.Strategy):
    def __init__(self):
        pass

    def next(self):
        # Get the current date and time
        current_datetime = '2023-12-12 00:00:00'
        current_hour = '01:00:00'

        print(f"current_datetime: {current_datetime}, current_hour: {current_hour}")

        # Slice the predictions based on the current date and hour
        signal = predictions_df["Predicted"].loc['2023-12-21 00:00:00']

        # Get account information to check available quantity of ETHUSD
        position_info = api.get_position('ETHUSD')
        ethusd_qty_available = float(position_info.qty)

        # Execute trades based on your signals
        if signal == 1 and ethusd_qty_available > 0:
            # Place a market order to buy
            self.buy(data=self.datas[0], size=1)
        elif signal == -1 and ethusd_qty_available > 0:
            # Place a market order to sell
            self.sell(data=self.datas[0], size=1)

# Convert Yahoo Finance data to Backtrader data feed
class YahooFinanceData(bt.feeds.PandasData):
    params = (
        ('datetime', 'Date'),
        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Close'),
        ('volume', 'Volume'),
        ('openinterest', None),
    )

# Create a Backtrader Cerebro engine
cerebro = bt.Cerebro()

# Download Yahoo Finance data for ETH-USD
symbol = 'ETH-USD'
yf_data = yf.download(symbol, start='2023-12-12', end='2023-12-21')  # Adjust start and end dates
yf_data['Date'] = yf_data.index  # Create a 'Date' column from the index
data = YahooFinanceData(dataname=yf_data)

# Add the data feed to the engine
cerebro.adddata(data)

# Add the strategy
cerebro.addstrategy(MyStrategy)

# Run the backtest
cerebro.run()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_25092\788305642.py:12: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   predictions_df = pd.read_csv('ETH_AUG_predictions.csv', index_col="date", parse_dates=True, infer_datetime_format=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 12
#       9 api = tradeapi.REST('PKD8BNDR0EC8XAJCLZDY', 'gAgLE5vv1g90cncwc0SQO4K13TeeFwI2gr7caf7p', base_url='https://paper-api.alpaca.markets')  # Use the paper trading API for testing
#      11 # Define your prediction data or replace this with loading your actual prediction data
# ---> 12 predictions_df = pd.read_csv('ETH_AUG_predictions.csv', index_col="date", parse_dates=True, infer_datetime_format=True)
#      14 # Define a Backtrader strategy
#      15 class MyStrategy(bt.Strategy):
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:162, in CParserWrapper.__init__(self, src, **kwds)
#     160 # error: Cannot determine type of 'names'
#     161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
# --> 162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#     165 self.orig_names = self.names  # type: ignore[has-type]
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper._set_noconvert_columns(self)
#     213 col_indices = [names_dict[x] for x in self.names]  # type: ignore[has-type]
#     214 # error: Cannot determine type of 'names'
# --> 215 noconvert_columns = self._set_noconvert_dtype_columns(
#     216     col_indices,
#     217     self.names,  # type: ignore[has-type]
#     218 )
#     219 for col in noconvert_columns:
#     220     self._reader.set_noconvert(col)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\base_parser.py:663, in ParserBase._set_noconvert_dtype_columns(self, col_indices, names)
#     661 if isinstance(self.index_col, list):
#     662     for k in self.index_col:
# --> 663         noconvert_columns.add(_set(k))
#     664 elif self.index_col is not None:
#     665     noconvert_columns.add(_set(self.index_col))
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\base_parser.py:640, in ParserBase._set_noconvert_dtype_columns.<locals>._set(x)
#     637     x = usecols[x]
#     639 if not is_integer(x):
# --> 640     x = col_indices[names.index(x)]
#     642 return x
#
# ValueError: 'date' is not in list
