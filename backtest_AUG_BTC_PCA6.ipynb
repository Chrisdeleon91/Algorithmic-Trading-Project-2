# %% [markdown]
# # 1 Month Test of Bitcoin Backtesting Using Augmento Sentiment and PCA

# %%
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
import time
import backtrader as bt
import pandas as pd
import yfinance as yf
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Initialize Alpaca API
api = tradeapi.REST('PKQD2ND8DVB2JMRYN7RU', 'P7G64gQ0PjnK4LZZ3V7R04qLdJj9WC9ajifMN52Z', base_url='https://paper-api.alpaca.markets')

# Define your prediction data or replace this with loading your actual prediction data
predictions_df = pd.read_csv('Resources\BTC_AUG_PCA6_predictions.csv', parse_dates=True, infer_datetime_format=True)

# Set the date range based on yf_data and predictions_df
symbol = 'BTC-USD'
start_date = '2023-11-22'
end_date = '2023-12-22'

# Filter predictions_df based on the date range
predictions_df = predictions_df[(predictions_df['date'] >= start_date) & (predictions_df['date'] <= end_date)]

# Convert Yahoo Finance data to Backtrader data feed
class YahooFinanceData(bt.feeds.PandasData):
    params = (
        ('datetime', 'Date'),
        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Close'),
        ('volume', 'Volume'),
        ('openinterest', None),
    )

# Create a Backtrader Cerebro engine
cerebro = bt.Cerebro()

# Set our desired cash start to $100,000
cerebro.broker.setcash(100000)
print('Starting Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())

# Download Yahoo Finance data for BTC-USD with hourly frequency over the specified date range
yf_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')  # Adjust start and end dates
yf_data['Date'] = yf_data.index  # Create a 'Date' column from the index
yf_data.to_csv('Resources\BTC_yf_data_1_month.csv', index='Date')
data = YahooFinanceData(dataname=yf_data)

# Add the data feed to the engine with a specific time range
cerebro.adddata(data)

# Define a Backtrader strategy
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.signal_index = 0  # Index to keep track of the current signal in predictions_df

    def next(self):
        # Get the current date and time from the data feed
        current_datetime = self.datas[0].datetime.datetime()

        # Check if there are more signals in predictions_df
        if self.signal_index < len(predictions_df):
            # Get the corresponding signal from predictions_df
            signal_datetime = predictions_df.iloc[self.signal_index]['date']
            signal = predictions_df.iloc[self.signal_index]['Predicted']

            # Execute trades based on your signals
            if signal == 1:
                # Place a market order to buy
                self.buy(data=self.datas[0], size=1)
            elif signal == -1:
                # Place a market order to sell
                self.sell(data=self.datas[0], size=1)

            # Move to the next signal in predictions_df
            self.signal_index += 1

# Add the strategy
cerebro.addstrategy(MyStrategy)

# Run the backtest
cerebro.run()

# Print the final results
print('Final Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())
btc_sma_value = cerebro.broker.getvalue()
initial_investment = 100000
pnl_sma_btc = round(btc_sma_value - initial_investment, 2)
print(f'BTC had a ${pnl_sma_btc} profit amount over its initial investment of ${initial_investment}')
percentage = round(pnl_sma_btc/initial_investment,2)
print(f'with a profit percentage of {percentage}%.')

# Plot and save the figure
btc_sma_plot = cerebro.plot(iplot=False, volume=True, savefig=True, figfilename='btc-backtrader-plot.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#      13 api = tradeapi.REST('PKQD2ND8DVB2JMRYN7RU', 'P7G64gQ0PjnK4LZZ3V7R04qLdJj9WC9ajifMN52Z', base_url='https://paper-api.alpaca.markets')
#      15 # Define your prediction data or replace this with loading your actual prediction data
# ---> 16 predictions_df = pd.read_csv('Resources\BTC_AUG_PCA6_predictions.csv', parse_dates=True, infer_datetime_format=True)
#      18 # Set the date range based on yf_data and predictions_df
#      19 symbol = 'BTC-USD'
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources\\BTC_AUG_PCA6_predictions.csv'

# %% [markdown]
# # 1 Week of Bitcoin Backtesting Using Augmento Sentiment and PCA

# %%
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
import time
import backtrader as bt
import pandas as pd
import yfinance as yf
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Initialize Alpaca API
api = tradeapi.REST('PKQD2ND8DVB2JMRYN7RU', 'P7G64gQ0PjnK4LZZ3V7R04qLdJj9WC9ajifMN52Z', base_url='https://paper-api.alpaca.markets')

# Define your prediction data or replace this with loading your actual prediction data
predictions_df = pd.read_csv('Resources\BTC_AUG_PCA6_predictions.csv', parse_dates=True, infer_datetime_format=True)

# Set the date range based on yf_data and predictions_df
symbol = 'BTC-USD'
start_date = '2023-12-15'
end_date = '2023-12-22'

# Filter predictions_df based on the date range
predictions_df = predictions_df[(predictions_df['date'] >= start_date) & (predictions_df['date'] <= end_date)]

# Convert Yahoo Finance data to Backtrader data feed
class YahooFinanceData(bt.feeds.PandasData):
    params = (
        ('datetime', 'Date'),
        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Close'),
        ('volume', 'Volume'),
        ('openinterest', None),
    )

# Create a Backtrader Cerebro engine
cerebro = bt.Cerebro()

# Set our desired cash start to $100,000
cerebro.broker.setcash(100000)
print('Starting Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())

# Download Yahoo Finance data for BTC-USD with hourly frequency over the specified date range
yf_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')  # Adjust start and end dates
yf_data['Date'] = yf_data.index  # Create a 'Date' column from the index
yf_data.to_csv('Resources\BTC_yf_data_1_week.csv', index='Date')
data = YahooFinanceData(dataname=yf_data)

# Add the data feed to the engine with a specific time range
cerebro.adddata(data)

# Define a Backtrader strategy
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.signal_index = 0  # Index to keep track of the current signal in predictions_df

    def next(self):
        # Get the current date and time from the data feed
        current_datetime = self.datas[0].datetime.datetime()

        # Check if there are more signals in predictions_df
        if self.signal_index < len(predictions_df):
            # Get the corresponding signal from predictions_df
            signal_datetime = predictions_df.iloc[self.signal_index]['date']
            signal = predictions_df.iloc[self.signal_index]['Predicted']

            # Execute trades based on your signals
            if signal == 1:
                # Place a market order to buy
                self.buy(data=self.datas[0], size=1)
            elif signal == -1:
                # Place a market order to sell
                self.sell(data=self.datas[0], size=1)

            # Move to the next signal in predictions_df
            self.signal_index += 1

# Add the strategy
cerebro.addstrategy(MyStrategy)

# Run the backtest
cerebro.run()

# Print the final results
print('Final Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())
btc_sma_value = cerebro.broker.getvalue()
initial_investment = 100000
pnl_sma_btc = round(btc_sma_value - initial_investment, 2)
print(f'BTC had a ${pnl_sma_btc} profit amount over its initial investment of ${initial_investment}')
percentage = round(pnl_sma_btc/initial_investment,2)
print(f'with a profit percentage of {percentage}%.')

# Plot and save the figure
btc_sma_plot = cerebro.plot(iplot=False, volume=True, savefig=True, figfilename='btc-backtrader-plot.png')
# Out:
# Starting Portfolio Value for BTC: $100000.00
# [*********************100%%**********************]  1 of 1 completed
# Final Portfolio Value for BTC: $-125811.68
# BTC had a $-225811.68 profit amount over its initial investment of $100000
# with a profit percentage of -2.26%.
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
# ...
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# Traceback (most recent call last):
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\cbook\__init__.py", line 309, in process
#     func(*args, **kwargs)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 221, in onmove
#     self._update(event)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\multicursor.py", line 230, in _update
#     ax.draw_artist(line)
#   File "c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py", line 3074, in draw_artist
#     a.draw(self.figure.canvas.get_renderer())
# AttributeError: 'NoneType' object has no attribute 'canvas'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 96
#      93 print(f'with a profit percentage of {percentage}%.')
#      95 # Plot and save the figure
# ---> 96 btc_sma_plot = cerebro.plot(iplot=False, volume=True, savefig=True, figfilename='btc-backtrader-plot.png')
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\cerebro.py:1001, in Cerebro.plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     997         # pfillers=pfillers2)
#     999         figs.append(rfig)
# -> 1001     plotter.show()
#    1003 return figs
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\backtrader\plot\plot.py:821, in Plot_OldSync.show(self)
#     820 def show(self):
# --> 821     self.mpyplot.show()
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backend_bases.py:3620, in _Backend.show(cls, block)
#    3618     block = not ipython_pylab and not is_interactive()
#    3619 if block:
# -> 3620     cls.mainloop()
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backends\_backend_tk.py:523, in FigureManagerTk.start_main_loop(cls)
#     521 manager_class._owns_mainloop = True
#     522 try:
# --> 523     first_manager.window.mainloop()
#     524 finally:
#     525     manager_class._owns_mainloop = False
#
# File c:\Users\chris\anaconda3\envs\dev\lib\tkinter\__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %% [markdown]
# # 3 Days of Bitcoin Backtesting Using Augmento Sentiment and PCA

# %%
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
import time
import backtrader as bt
import pandas as pd
import yfinance as yf
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Initialize Alpaca API
api = tradeapi.REST('PKQD2ND8DVB2JMRYN7RU', 'P7G64gQ0PjnK4LZZ3V7R04qLdJj9WC9ajifMN52Z', base_url='https://paper-api.alpaca.markets')

# Define your prediction data or replace this with loading your actual prediction data
predictions_df = pd.read_csv('Resources\BTC_AUG_PCA6_predictions.csv', parse_dates=True, infer_datetime_format=True)

# Set the date range based on yf_data and predictions_df
symbol = 'BTC-USD'
start_date = '2023-12-17'
end_date = '2023-12-19'

# Filter predictions_df based on the date range
predictions_df = predictions_df[(predictions_df['date'] >= start_date) & (predictions_df['date'] <= end_date)]

# Convert Yahoo Finance data to Backtrader data feed
class YahooFinanceData(bt.feeds.PandasData):
    params = (
        ('datetime', 'Date'),
        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Close'),
        ('volume', 'Volume'),
        ('openinterest', None),
    )

# Create a Backtrader Cerebro engine
cerebro = bt.Cerebro()

# Set our desired cash start to $100,000
cerebro.broker.setcash(100000)
print('Starting Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())

# Download Yahoo Finance data for BTC-USD with hourly frequency over the specified date range
yf_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')  # Adjust start and end dates
yf_data['Date'] = yf_data.index  # Create a 'Date' column from the index
yf_data.to_csv('Resources\BTC_yf_data_3_days.csv', index='Date')
data = YahooFinanceData(dataname=yf_data)

# Add the data feed to the engine with a specific time range
cerebro.adddata(data)

# Define a Backtrader strategy
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.signal_index = 0  # Index to keep track of the current signal in predictions_df

    def next(self):
        # Get the current date and time from the data feed
        current_datetime = self.datas[0].datetime.datetime()

        # Check if there are more signals in predictions_df
        if self.signal_index < len(predictions_df):
            # Get the corresponding signal from predictions_df
            signal_datetime = predictions_df.iloc[self.signal_index]['date']
            signal = predictions_df.iloc[self.signal_index]['Predicted']

            # Execute trades based on your signals
            if signal == 1:
                # Place a market order to buy
                self.buy(data=self.datas[0], size=1)
            elif signal == -1:
                # Place a market order to sell
                self.sell(data=self.datas[0], size=1)

            # Move to the next signal in predictions_df
            self.signal_index += 1

# Add the strategy
cerebro.addstrategy(MyStrategy)

# Run the backtest
cerebro.run()

# Print the final results
print('Final Portfolio Value for BTC: $%.2f' % cerebro.broker.getvalue())
btc_sma_value = cerebro.broker.getvalue()
initial_investment = 100000
pnl_sma_btc = round(btc_sma_value - initial_investment, 2)
print(f'BTC had a ${pnl_sma_btc} profit amount over its initial investment of ${initial_investment}')
percentage = round(pnl_sma_btc/initial_investment,2)
print(f'with a profit percentage of {percentage}%.')

# Plot and save the figure
btc_sma_plot = cerebro.plot(iplot=False, volume=True, savefig=True, figfilename='btc-backtrader-plot.png')
# Out:
# Starting Portfolio Value for BTC: $100000.00
# [*********************100%%**********************]  1 of 1 completed
# Final Portfolio Value for BTC: $52948.19
# BTC had a $-47051.81 profit amount over its initial investment of $100000
# with a profit percentage of -0.47%.
